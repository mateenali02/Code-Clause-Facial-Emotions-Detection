# %% [markdown]
# <a href="https://colab.research.google.com/github/mateenali02/Code-Clause-Facial-Emotions-Detection/blob/main/test_CodeClause.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Facial Emotions Detection Internship Project
# ### by Mir Abdul Mateen Ali

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from keras.models import load_model

# %%
model=load_model('/content/drive/MyDrive/Facial Emotion Recognition/model_file.h5')

# %%
faceDetect=cv2.CascadeClassifier('/content/drive/MyDrive/Facial Emotion Recognition/haarcascade_frontalface_default.xml')

# %%
labels_dict={0:'Angry',1:'Disgust', 2:'Fear', 3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

# %%
frame=cv2.imread("/content/drive/MyDrive/Facial Emotion Recognition/faces-small.jpg")
gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faces= faceDetect.detectMultiScale(gray, 1.3, 3)

# %%
for x,y,w,h in faces:
    sub_face_img=gray[y:y+h, x:x+w]
    resized=cv2.resize(sub_face_img,(48,48))
    normalize=resized/255.0
    reshaped=np.reshape(normalize, (1, 48, 48, 1))
    result=model.predict(reshaped)
    label=np.argmax(result, axis=1)[0]
    print(label)
    cv2.rectangle(frame, (x,y), (x+w, y+h), (0,0,255), 1)
    cv2.rectangle(frame,(x,y),(x+w,y+h),(50,50,255),2)
    cv2.rectangle(frame,(x,y-40),(x+w,y),(50,50,255),-1)
    cv2.putText(frame, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
# Out:
# 1/1 [==============================] - 0s 325ms/step
# 3
# 1/1 [==============================] - 0s 27ms/step
# 0
# 1/1 [==============================] - 0s 27ms/step
# 0
# 1/1 [==============================] - 0s 29ms/step
# 6
# 1/1 [==============================] - 0s 33ms/step
# 3
# 1/1 [==============================] - 0s 28ms/step
# 4
# 1/1 [==============================] - 0s 27ms/step
# 0
# 1/1 [==============================] - 0s 30ms/step
# 1
# 1/1 [==============================] - 0s 28ms/step
# 3
# 1/1 [==============================] - 0s 46ms/step
# 3
# 1/1 [==============================] - 0s 29ms/step
# 0
# 1/1 [==============================] - 0s 35ms/step
# 5
# 1/1 [==============================] - 0s 29ms/step
# 4
# 1/1 [==============================] - 0s 29ms/step
# 4
# 1/1 [==============================] - 0s 38ms/step
# 3
# 1/1 [==============================] - 0s 49ms/step
# 1

# %%
cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F979A318280>

# %%
frame=cv2.imread("/content/drive/MyDrive/Facial Emotion Recognition/testing1.png")
gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
faces= faceDetect.detectMultiScale(gray, 1.3, 3)

# %%
for x,y,w,h in faces:
    sub_face_img=gray[y:y+h, x:x+w]
    resized=cv2.resize(sub_face_img,(48,48))
    normalize=resized/255.0
    reshaped=np.reshape(normalize, (1, 48, 48, 1))
    result=model.predict(reshaped)
    label=np.argmax(result, axis=1)[0]
    print(label)
    cv2.rectangle(frame, (x,y), (x+w, y+h), (0,0,255), 1)
    cv2.rectangle(frame,(x,y),(x+w,y+h),(50,50,255),2)
    cv2.rectangle(frame,(x,y-40),(x+w,y),(50,50,255),-1)
    cv2.putText(frame, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 0
# 1/1 [==============================] - 0s 31ms/step
# 0
# 1/1 [==============================] - 0s 31ms/step
# 4
# 1/1 [==============================] - 0s 35ms/step
# 3
# 1/1 [==============================] - 0s 32ms/step
# 6
# 1/1 [==============================] - 0s 28ms/step
# 3
# 1/1 [==============================] - 0s 28ms/step
# 3
# 1/1 [==============================] - 0s 26ms/step
# 0
# 1/1 [==============================] - 0s 25ms/step
# 0
# 1/1 [==============================] - 0s 29ms/step
# 4
# 1/1 [==============================] - 0s 31ms/step
# 2
# 1/1 [==============================] - 0s 36ms/step
# 4
# 1/1 [==============================] - 0s 30ms/step
# 4
# 1/1 [==============================] - 0s 26ms/step
# 4
# 1/1 [==============================] - 0s 31ms/step
# 2
# 1/1 [==============================] - 0s 29ms/step
# 3
# 1/1 [==============================] - 0s 27ms/step
# 0
# ...

# %%
cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=538x299 at 0x7F979A319F60>
